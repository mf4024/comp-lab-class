# %%
import os
import sys
import pandas as pd
import numpy as np
from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole
from psikit import Psikit
import matplotlib.pyplot as plt

# %%
pk=Psikit(debug=True,threads=1,memory=12)
# Out:
#   Memory set to  11.176 GiB by Python driver.
#   Threads set to 1 by Python driver.

# %%
pk.read_from_smiles('c1ccncc1')

# %%
pk.optimize()
# Out:
# Optimizer: Optimization complete!
# -246.70419461542934

# %%
pk.mol

# %%
print(pk.calc_resp_charges())
print(pk.calc_mulliken_charges())
print(pk.calc_lowdin_charges())
# Out:
# [-0.01791559 -0.27842227  0.26755264 -0.55317034  0.27044983 -0.27224729
#   0.14363118  0.14293348  0.0797274   0.07746522  0.13999573]
# [-0.08997404 -0.20494836  0.12798579 -0.53578653  0.12798579 -0.20494835
#   0.16211514  0.15725379  0.15153149  0.15153149  0.15725379]
# [-0.06364573 -0.14772611 -0.00226373 -0.19366385 -0.00433247 -0.14557574
#   0.11782564  0.11446044  0.10518783  0.10705782  0.1126759 ]

# %%
mol = pk.mol
atoms = mol.GetAtoms()

# %%
data = {'Symbol':[atom.GetSymbol() for atom in atoms],
        'RESP': [float(atom.GetProp('RESP')) for atom in atoms],
        'MULLIKEN': [float(atom.GetProp('MULLIKEN')) for atom in atoms],
       'LOWDIN':  [float(atom.GetProp('LOWDIN')) for atom in atoms]}

# %%
df = pd.DataFrame(data)

# %%
df.round(3)
# Out:
#    Symbol   RESP  MULLIKEN  LOWDIN
# 0       C -0.018    -0.090  -0.064
# 1       C -0.278    -0.205  -0.148
# 2       C  0.268     0.128  -0.002
# 3       N -0.553    -0.536  -0.194
# 4       C  0.270     0.128  -0.004
# 5       C -0.272    -0.205  -0.146
# 6       H  0.144     0.162   0.118
# 7       H  0.143     0.157   0.114
# 8       H  0.080     0.152   0.105
# 9       H  0.077     0.152   0.107
# 10      H  0.140     0.157   0.113

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
plt.scatter(df.RESP, df.MULLIKEN)
plt.xlabel('RESP')
plt.ylabel('MULLIKEN')
plt.plot(np.arange(-1.0, 1.0, 0.01), np.arange(-1.0, 1.0, 0.01), c='b')

# %%
plt.scatter(df.RESP, df.LOWDIN)
plt.xlabel('RESP')
plt.ylabel('LOWDIN')
plt.plot(np.arange(-1.0, 1.0, 0.01), np.arange(-1.0, 1.0, 0.01), c='b')

# %%
plt.scatter(df.MULLIKEN, df.LOWDIN)
plt.xlabel('MULLIKEN')
plt.ylabel('LOWDIN')
plt.plot(np.arange(-1.0, 1.0, 0.01), np.arange(-1.0, 1.0, 0.01), c='b')

# %%
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem.Draw import IPythonConsole
IPythonConsole.molSize = 250,250

# %%
m = pk.mol 
m

# %%
m = Chem.MolFromSmiles('c1ccncc1')
AllChem.ComputeGasteigerCharges(m)

m2 = Chem.Mol(m)
i = 0
for at in m2.GetAtoms():
    id= at.GetIdx()
    lbl = '%.2f'%df.at[id,'RESP']
    at.SetProp('atomNote',lbl)
    i += 1
m2

# %%
df.keys()
# Out:
# Index(['Symbol', 'RESP', 'MULLIKEN', 'LOWDIN'], dtype='object')
