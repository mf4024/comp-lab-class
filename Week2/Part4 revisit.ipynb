# %%
import matplotlib.pyplot as plt
import sys
import numpy as np
def read_xvg(filename):
    with open(filename, 'r') as f:
        lines = f.readlines()
        data = []
        for line in lines:
            if line.startswith('#'):
                continue
            if line.startswith('@'):
                continue
            if line.startswith('&'):
                continue
            if line.startswith('*'):
                continue
            data.append(line.split())
    return np.array(data, dtype=np.float)
read_xvg("1hz3_T310.run.25000000.energy.xvg")
# Out:
# array([[ 0.00000000e+00, -1.75680938e+05,  3.51286445e+04, ...,
#          3.09853302e+02,  8.49674380e+01,  1.37956879e+02],
#        [ 1.00000000e+02, -1.75387062e+05,  3.57370156e+04, ...,
#          3.15219452e+02,  1.16084549e+02,  1.37819077e+02],
#        [ 2.00000000e+02, -1.75059531e+05,  3.54017891e+04, ...,
#          3.12262573e+02, -8.57273560e+01,  1.37437531e+02],
#        ...,
#        [ 4.98000000e+04, -1.75233297e+05,  3.50128906e+04, ...,
#          3.08832306e+02,  2.57780910e+01,  1.38378967e+02],
#        [ 4.99000000e+04, -1.75552906e+05,  3.55344883e+04, ...,
#          3.13433105e+02, -1.33103729e+02,  1.38065186e+02],
#        [ 5.00000000e+04, -1.75183906e+05,  3.48670312e+04, ...,
#          3.07545776e+02, -1.32031494e+02,  1.38603043e+02]])

# %%
def plot_Potentialxvg(filename):
    data = read_xvg(filename)
    #convert pico second to nanosecond
    data[:,0] = data[:,0] * 0.001
    plt.plot(data[:,0], data[:,1])
    #Plot title
    plt.title("Potential vs Time")
    #X-axis label
    plt.xlabel('Time (ns)')
    #Y-axis label
    plt.ylabel('Potential (J)')
    plt.rcParams["figure.figsize"] = (20,10)
    plt.show()
plot_Potentialxvg("1hz3_T310.run.25000000.energy.xvg")

# %%
def plot_xvgKinetic(filename):
    data = read_xvg(filename)
    #convert pico second to nanosecond
    data[:,0] = data[:,0] * 0.001
    #convert J/mol to KJ/mol
    data[:,2] = data[:,2] * 0.001
    plt.plot(data[:,0], data[:,2])
    #Plot title
    plt.title("Kinetic En. vs Time")
    #X-axis label
    plt.xlabel('Time (ns)')
    #Y-axis label
    plt.ylabel('Kinetic En. (KJ/mol)')
    plt.show()  
    plt.rcParams["figure.figsize"] = (20,10)    
plot_xvgKinetic("1hz3_T310.run.25000000.energy.xvg")

# %%
def plot_xvgTotal(filename):
    data = read_xvg(filename)
    #convert pico second to nanosecond
    data[:,0] = data[:,0] * 0.001
    plt.plot(data[:,0], data[:,3])
    #Plot title
    plt.title("Total En. vs Time")
    #X-axis label
    plt.xlabel('Time (ns)')
    #Y-axis label
    plt.ylabel('Total En. (KJ/mol)')
    plt.rcParams["figure.figsize"] = (20,10)
    plt.show()
plot_xvgTotal("1hz3_T310.run.25000000.energy.xvg")

# %%
def plot_xvgTemp(filename):
    data = read_xvg(filename)
    #convert pico second to nanosecond
    data[:,0] = data[:,0] * 0.001
    plt.plot(data[:,0], data[:,4])
    #Plot title
    plt.title("Temperature vs Time")
    #X-axis label
    plt.xlabel('Time (ns)')
    #Y-axis label
    plt.ylabel('Temperature (K)')
    plt.rcParams["figure.figsize"] = (20,10)
    plt.show()
plot_xvgTemp("1hz3_T310.run.25000000.energy.xvg")

# %%
def plot_xvgPressure(filename):
    data = read_xvg(filename)
    #convert pico second to nanosecond
    data[:,0] = data[:,0] * 0.001
    plt.plot(data[:,0], data[:,5])
    #Plot title
    plt.title("Pressure vs Time")
    #X-axis label
    plt.xlabel('Time (ns)')
    #Y-axis label
    plt.ylabel('Pressure (bar)')
    plt.rcParams["figure.figsize"] = (20,10)
    plt.show()
plot_xvgPressure("1hz3_T310.run.25000000.energy.xvg")

# %%
def plot_xvgVolume(filename):
    data = read_xvg(filename)
    #convert pico second to nanosecond
    data[:,0] = data[:,0] * 0.001
    plt.plot(data[:,0], data[:,6])
    #Plot title
    plt.title("Volume vs Time")
    #X-axis label
    plt.xlabel('Time (ns)')
    #Y-axis label
    plt.ylabel('Volume (nm^3)')
    plt.rcParams["figure.figsize"] = (20,10)
    plt.show()
plot_xvgVolume("1hz3_T310.run.25000000.energy.xvg")

# %%
def plot_xvgTempandKinetic(filename):
    data = read_xvg(filename)
    #convert pico second to nanosecond
    data[:,0] = data[:,0] * 0.001
    #convert J/mol to KJ/mol
    data[:,2] = data[:,2] * 0.001
    plt.plot(data[:,0], data[:,4], label="Temperature")
    plt.ylim(280, 320)
    #Plot title
    plt.title("Kinetic En. and Temp. vs Time")
    #X-axis label
    plt.xlabel('Time (ns)')
    #Y-axis label
    plt.ylabel('Temp. (K)')
    #Creating an another y-axis
    plt.twinx()
    plt.ylabel('Kinetic En. (KJ/mol)')
    plt.ylim(30, 60)
    #Change a color of the line
    plt.plot(data[:,0], data[:,2], label="Kinetic Energy (KJ/mol)", color="red")
    plt.rcParams["figure.figsize"] = (20,10)
    #Create legend
plot_xvgTempandKinetic("1hz3_T310.run.25000000.energy.xvg")
