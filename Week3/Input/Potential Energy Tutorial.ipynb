# %%
import mdtraj as md
import matplotlib.pyplot as plt
import numpy as np
def read_xvg(filename):
    with open(filename, 'r') as f:
        lines = f.readlines()
        data = []
        for line in lines:
            if line.startswith('#'):
                continue
            if line.startswith('@'):
                continue
            if line.startswith('&'):
                continue
            if line.startswith('*'):
                continue
            data.append(line.split())
    return np.array(data, dtype=float)
read_xvg('potential.xvg')
# Out:
# array([[ 0.00000000e+00, -3.30100938e+05],
#        [ 1.00000000e+00, -3.46918500e+05],
#        [ 2.00000000e+00, -3.70087875e+05],
#        ...,
#        [ 8.08000000e+02, -5.86274562e+05],
#        [ 8.09000000e+02, -5.86275562e+05],
#        [ 8.11000000e+02, -5.86344062e+05]])

# %%
#Plot xvg file
data = read_xvg('potential.xvg')
#Convert data[:,1] scientific notation to float
data[:,1] = data[:,1].astype(float)
#Express y-axis as scientific notation
plt.plot(data[:,0], data[:,1])
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
plt.xlabel('Energy Minimization Step')
plt.ylabel('Potential Energy (KJ/mol)')
plt.title('Potential Energy/Energy Minim')
plt.show()
