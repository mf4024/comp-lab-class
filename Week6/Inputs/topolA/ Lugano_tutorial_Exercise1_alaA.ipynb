# %%
import sys
import numpy as np
import matplotlib.pyplot as plt

#Read the grid file
grid = np.genfromtxt('HILLS')

#Plot the negative of the energy column
plt.scatter(grid[:,0]/1000, grid[:,5])
#convert the x axis from ps to ns

#label the axes
plt.xlabel('Time (ns)')
plt.ylabel('Energy(KJ/mol)')
plt.title('the Gaussian height of Alanine A')
plt.show()
#Save the plot
plt.savefig('height_of_dialaA.png')

# %%
plt.scatter(grid[:,0]/1000, grid[:,2])
#label the axes
plt.xlabel('Time')
plt.ylabel('Raidan')
plt.title('Time evolution of the metadynamics CV')
plt.show()
#Save the plot
plt.savefig('10ns of the metadynamics CV')
